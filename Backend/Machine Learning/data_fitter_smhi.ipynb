# %%
"""Data Processing for the SMHI data.
https://www.smhi.se/data/meteorologi/ladda-ner-meteorologiska-observationer#param=airtemperatureInstant,stations=active,stationid=97200
"""
__author__ = "Casper Kristiansson"
__copyright__ = "WeatherBrain"

__maintainer__ = "Casper Kristiansson"
__email__ = "casperkr@kth.se"
__status__ = "Development"

# %%
import pandas as pd
import datetime

# %%
temperature_dataframe = pd.read_excel('..\\Data\\Raw Data\\smhi\\smhi-opendata_1_97200_20220419_071322.xlsx')
temperature_last_months_dataframe = pd.read_excel('..\\Data\\Raw Data\\smhi\\smhi-opendata_1_97200_20220419_071323.xlsx')

# %%
temperature_dataframe.head(25)
# Out:
#                   Stationsnamn               Klimatnummer  \
# 0   Stockholm-Bromma Flygplats                      97200
# 1                          NaN                        NaN
# 2                Parameternamn                Beskrivning
# 3               Lufttemperatur  momentanvärde, 1 gång/tim
# 4                          NaN                        NaN
# 5          Tidsperiod (fr.o.m)         Tidsperiod (t.o.m)
# 6          1949-01-01 00:00:00        2022-04-01 07:00:00
# 7                          NaN                        NaN
# 8                        Datum                  Tid (UTC)
# 9          1949-01-01 00:00:00                   00:00:00
# 10         1949-01-01 00:00:00                   06:00:00
# 11         1949-01-01 00:00:00                   12:00:00
# 12         1949-01-01 00:00:00                   18:00:00
# 13         1949-01-02 00:00:00                   00:00:00
# 14         1949-01-02 00:00:00                   06:00:00
# 15         1949-01-02 00:00:00                   12:00:00
# 16         1949-01-02 00:00:00                   18:00:00
# 17         1949-01-03 00:00:00                   00:00:00
# 18         1949-01-03 00:00:00                   06:00:00
# 19         1949-01-03 00:00:00                   12:00:00
# 20         1949-01-03 00:00:00                   18:00:00
# 21         1949-01-04 00:00:00                   00:00:00
# 22         1949-01-04 00:00:00                   06:00:00
# 23         1949-01-04 00:00:00                   12:00:00
# 24         1949-01-04 00:00:00                   18:00:00
#
#    Mäthöjd (meter över marken)               Unnamed: 3  \
# 0                          2.0                      NaN
# 1                          NaN                      NaN
# 2                        Enhet                      NaN
# 3               degree celsius                      NaN
# 4                          NaN                      NaN
# 5      Höjd (meter över havet)  Latitud (decimalgrader)
# 6                         14.0                  59.3537
# 7                          NaN                      NaN
# 8               Lufttemperatur                 Kvalitet
# 9                          2.0                        Y
# 10                         3.3                        Y
# 11                         3.5                        Y
# 12                         3.4                        Y
# 13                         4.0                        Y
# 14                         4.4                        Y
# 15                         4.2                        Y
# 16                         4.8                        Y
# 17                         3.9                        Y
# 18                         4.1                        Y
# 19                         4.0                        Y
# 20                         2.3                        Y
# 21                         2.8                        Y
# 22                         2.6                        Y
# 23                         0.7                        Y
# 24                        -0.5                        Y
#
#                   Unnamed: 4  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5   Longitud (decimalgrader)
# 6                    17.9513
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
#
#                                            Unnamed: 5
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                        Tidsutsnitt:
# 9   Kvalitetskontrollerade historiska data (utom d...
# 10   Tidsperiod (fr.o.m.) = 1949-01-01 00:00:00 (UTC)
# 11    Tidsperiod (t.o.m.) = 2022-01-01 06:00:00 (UTC)
# 12                          Samplingstid = Ej angivet
# 13                                                NaN
# 14                                  Kvalitetskoderna:
# 15      Grön (G) = Kontrollerade och godkända värden.
# 16  Gul (Y) = Misstänkta eller aggregerade värden....
# 17                                                NaN
# 18                         Orsaker till saknade data:
# 19     stationen eller givaren har varit ur funktion.
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN

# %%
temperature_dataframe.drop(columns=['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], inplace=True)
temperature_last_months_dataframe.drop(columns=['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], inplace=True)

temperature_dataframe.head()
# Out:
#                  Stationsnamn               Klimatnummer  \
# 0  Stockholm-Bromma Flygplats                      97200
# 1                         NaN                        NaN
# 2               Parameternamn                Beskrivning
# 3              Lufttemperatur  momentanvärde, 1 gång/tim
# 4                         NaN                        NaN
#
#   Mäthöjd (meter över marken)
# 0                         2.0
# 1                         NaN
# 2                       Enhet
# 3              degree celsius
# 4                         NaN

# %%
temperature_dataframe.drop(range(9), inplace=True)
temperature_last_months_dataframe.drop(range(9), inplace=True)

temperature_dataframe.head()
# Out:
#            Stationsnamn Klimatnummer Mäthöjd (meter över marken)
# 9   1949-01-01 00:00:00     00:00:00                         2.0
# 10  1949-01-01 00:00:00     06:00:00                         3.3
# 11  1949-01-01 00:00:00     12:00:00                         3.5
# 12  1949-01-01 00:00:00     18:00:00                         3.4
# 13  1949-01-02 00:00:00     00:00:00                         4.0

# %%
temperature_dataframe.rename(columns={'Stationsnamn': 'Date', 'Klimatnummer': 'Time (h)', 'Mäthöjd (meter över marken)': 'Temperature'}, inplace=True)
temperature_last_months_dataframe.rename(columns={'Stationsnamn': 'Date', 'Klimatnummer': 'Time (h)', 'Mäthöjd (meter över marken)': 'Temperature'}, inplace=True)

temperature_dataframe.columns
# Out:
# Index(['Date', 'Time (h)', 'Temperature'], dtype='object')

# %%
temperature_dataframe = pd.concat([temperature_dataframe, temperature_last_months_dataframe], ignore_index=True)

temperature_dataframe.shape
# Out:
# (539378, 3)

# %%
air_pressure_dataframe = pd.read_excel('..\\Data\\Raw Data\\smhi\\smhi-opendata_9_97200_20220419_071543_2.xlsx')
air_pressure_last_months_dataframe = pd.read_excel('..\\Data\\Raw Data\\smhi\\smhi-opendata_9_97200_20220419_071558.xlsx')

# %%
air_pressure_dataframe.head(25)
# Out:
#                           Stationsnamn  \
# 0           Stockholm-Bromma Flygplats
# 1                                  NaN
# 2                        Parameternamn
# 3   Lufttryck reducerat havsytans nivå
# 4                                  NaN
# 5                  Tidsperiod (fr.o.m)
# 6                  1939-01-01 00:00:00
# 7                                  NaN
# 8                                Datum
# 9                  1939-01-01 00:00:00
# 10                 1939-01-01 00:00:00
# 11                 1939-01-01 00:00:00
# 12                 1939-01-01 00:00:00
# 13                 1939-01-02 00:00:00
# 14                 1939-01-02 00:00:00
# 15                 1939-01-02 00:00:00
# 16                 1939-01-02 00:00:00
# 17                 1939-01-03 00:00:00
# 18                 1939-01-03 00:00:00
# 19                 1939-01-03 00:00:00
# 20                 1939-01-03 00:00:00
# 21                 1939-01-04 00:00:00
# 22                 1939-01-04 00:00:00
# 23                 1939-01-04 00:00:00
# 24                 1939-01-04 00:00:00
#
#                                      Klimatnummer  \
# 0                                           97200
# 1                                             NaN
# 2                                     Beskrivning
# 3   vid havsytans nivå, momentanvärde, 1 gång/tim
# 4                                             NaN
# 5                              Tidsperiod (t.o.m)
# 6                             2022-04-01 12:00:00
# 7                                             NaN
# 8                                       Tid (UTC)
# 9                                        01:00:00
# 10                                       07:00:00
# 11                                       13:00:00
# 12                                       18:00:00
# 13                                       01:00:00
# 14                                       07:00:00
# 15                                       13:00:00
# 16                                       18:00:00
# 17                                       01:00:00
# 18                                       07:00:00
# 19                                       13:00:00
# 20                                       18:00:00
# 21                                       01:00:00
# 22                                       07:00:00
# 23                                       13:00:00
# 24                                       18:00:00
#
#            Mäthöjd (meter över marken)               Unnamed: 3  \
# 0                                  0.0                      NaN
# 1                                  NaN                      NaN
# 2                                Enhet                      NaN
# 3                          hectopascal                      NaN
# 4                                  NaN                      NaN
# 5              Höjd (meter över havet)  Latitud (decimalgrader)
# 6                                 14.0                  59.3537
# 7                                  NaN                      NaN
# 8   Lufttryck reducerat havsytans nivå                 Kvalitet
# 9                               1003.9                        Y
# 10                              1006.4                        Y
# 11                              1008.0                        Y
# 12                              1009.6                        Y
# 13                              1010.0                        Y
# 14                              1009.2                        Y
# 15                              1008.0                        Y
# 16                              1007.3                        Y
# 17                              1005.2                        Y
# 18                              1004.3                        Y
# 19                              1003.7                        Y
# 20                              1002.6                        Y
# 21                              1000.9                        Y
# 22                              1000.3                        Y
# 23                               999.7                        Y
# 24                               999.2                        Y
#
#                   Unnamed: 4  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5   Longitud (decimalgrader)
# 6                    17.9513
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
#
#                                            Unnamed: 5
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                        Tidsutsnitt:
# 9   Kvalitetskontrollerade historiska data (utom d...
# 10   Tidsperiod (fr.o.m.) = 1939-01-01 00:00:00 (UTC)
# 11    Tidsperiod (t.o.m.) = 2022-01-01 06:00:00 (UTC)
# 12                          Samplingstid = Ej angivet
# 13                                                NaN
# 14                                  Kvalitetskoderna:
# 15      Grön (G) = Kontrollerade och godkända värden.
# 16  Gul (Y) = Misstänkta eller aggregerade värden....
# 17                                                NaN
# 18                         Orsaker till saknade data:
# 19     stationen eller givaren har varit ur funktion.
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN

# %%
air_pressure_dataframe.drop(columns=['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], inplace=True)
air_pressure_last_months_dataframe.drop(columns=['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], inplace=True)

air_pressure_dataframe.head()
# Out:
#                          Stationsnamn  \
# 0          Stockholm-Bromma Flygplats
# 1                                 NaN
# 2                       Parameternamn
# 3  Lufttryck reducerat havsytans nivå
# 4                                 NaN
#
#                                     Klimatnummer Mäthöjd (meter över marken)
# 0                                          97200                         0.0
# 1                                            NaN                         NaN
# 2                                    Beskrivning                       Enhet
# 3  vid havsytans nivå, momentanvärde, 1 gång/tim                 hectopascal
# 4                                            NaN                         NaN

# %%
air_pressure_dataframe.drop(range(9), inplace=True)
air_pressure_last_months_dataframe.drop(range(9), inplace=True)

air_pressure_dataframe.head()
# Out:
#            Stationsnamn Klimatnummer Mäthöjd (meter över marken)
# 9   1939-01-01 00:00:00     01:00:00                      1003.9
# 10  1939-01-01 00:00:00     07:00:00                      1006.4
# 11  1939-01-01 00:00:00     13:00:00                      1008.0
# 12  1939-01-01 00:00:00     18:00:00                      1009.6
# 13  1939-01-02 00:00:00     01:00:00                      1010.0

# %%
air_pressure_dataframe.rename(columns={'Stationsnamn': 'Date', 'Klimatnummer': 'Time (h)', 'Mäthöjd (meter över marken)': 'Air Pressure'}, inplace=True)
air_pressure_last_months_dataframe.rename(columns={'Stationsnamn': 'Date', 'Klimatnummer': 'Time (h)', 'Mäthöjd (meter över marken)': 'Air Pressure'}, inplace=True)

air_pressure_dataframe.columns
# Out:
# Index(['Date', 'Time (h)', 'Air Pressure'], dtype='object')

# %%
air_pressure_dataframe = pd.concat([air_pressure_dataframe, air_pressure_last_months_dataframe], ignore_index=True)

air_pressure_dataframe.shape
# Out:
# (553874, 3)

# %%
result_df = pd.merge(temperature_dataframe, air_pressure_dataframe, on=['Date', 'Time (h)'])

# %%
result_df.head()
# Out:
#                   Date  Time (h) Temperature Air Pressure
# 0  1949-01-01 00:00:00  00:00:00         2.0        990.8
# 1  1949-01-01 00:00:00  06:00:00         3.3        985.7
# 2  1949-01-01 00:00:00  12:00:00         3.5        992.0
# 3  1949-01-01 00:00:00  18:00:00         3.4        993.0
# 4  1949-01-02 00:00:00  00:00:00         4.0        990.6

# %%
air_pressure_dataframe[air_pressure_dataframe['Date'] == datetime.datetime(1949, 1, 1)]
# Out:
#                       Date  Time (h) Air Pressure
# 12853  1949-01-01 00:00:00  00:00:00        990.8
# 12854  1949-01-01 00:00:00  06:00:00        985.7
# 12855  1949-01-01 00:00:00  12:00:00        992.0
# 12856  1949-01-01 00:00:00  18:00:00        993.0

# %%
temperature_dataframe[temperature_dataframe['Date'] == datetime.datetime(1949, 1, 1)]
# Out:
#                   Date  Time (h) Temperature
# 0  1949-01-01 00:00:00  00:00:00         2.0
# 1  1949-01-01 00:00:00  06:00:00         3.3
# 2  1949-01-01 00:00:00  12:00:00         3.5
# 3  1949-01-01 00:00:00  18:00:00         3.4

# %%
result_df.to_csv('..\\Data\\Processed Data\\smhi_data.csv', index=False)
